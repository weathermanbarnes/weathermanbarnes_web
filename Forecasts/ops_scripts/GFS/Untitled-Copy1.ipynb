# %%
import subprocess

#for t in range(-96,240,6):
subprocess.run(["python3", "poststamp_precip-GEFS.py", "20240923", "12", "48"])#str(t)])
# Out:
# 100%|██████████| 31/31 [00:38<00:00,  1.24s/it]
# /scratch/gb02/mb0427/Website/Forecasts/NOAA/GEFS/images/GEFS_Australia_PostagePrecip24hr_48.jpg Size: (7200, 5100) New Size: (414, 46, 7042, 4546)
# CompletedProcess(args=['python3', 'poststamp_precip-GEFS.py', '20240923', '12', '48'], returncode=0)

# %%
import xarray as xr

# %%
fn="/scratch/gb02/mb0427/Website/Forecasts/NOAA/GEFS/data/20240923120000-gea00-24h-gefs.grib2"
prcp=xr.open_dataset(fn,engine='cfgrib',
                      backend_kwargs={'filter_by_keys': {'shortName': 'u'}})

# %%
prcp
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:        (isobaricInhPa: 12, latitude: 361, longitude: 720)
# Coordinates:
#     number         int64 8B ...
#     time           datetime64[ns] 8B ...
#     step           timedelta64[ns] 8B ...
#   * isobaricInhPa  (isobaricInhPa) float64 96B 1e+03 925.0 850.0 ... 50.0 10.0
#   * latitude       (latitude) float64 3kB 90.0 89.5 89.0 ... -89.0 -89.5 -90.0
#   * longitude      (longitude) float64 6kB 0.0 0.5 1.0 1.5 ... 358.5 359.0 359.5
#     valid_time     datetime64[ns] 8B ...
# Data variables:
#     u              (isobaricInhPa, latitude, longitude) float32 12MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          2
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2024-09-24T15:36 GRIB to CDM+CF via cfgrib-0.9.1...
